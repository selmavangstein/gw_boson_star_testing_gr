# %% [markdown]
# # Fitting quasi-normal modes in A17A17q100d17p000

# %% [markdown]
# We begin with some standard imports and global settings.

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# Things we are playing with:
# - Analysis duration (0.2-0.6)
# - Cutoff time (6 or 10.5 tMf)
#
# - mass, luminosity dist (other file)
# - m-range for prior - adapt based on other params to get appropriate range

# %%
# %matplotlib widget
# %config InlineBackend.figure_format = 'retina'

# %%
# these are just some standard setup
# must edit to do GPU though - see tip below

# disable numpy multithreading to avoid conflicts (this is for jax on cpu I think)
# with jax multiprocessing in numpyro
import os
os.environ["OMP_NUM_THREADS"] = "1"
import numpy as np

# import jax and set it up to use double precision
from jax import config
config.update("jax_enable_x64", False)

# import numpyro and set it up to use 4 CPU devices
import numpyro
numpyro.set_host_device_count(4)
numpyro.set_platform('cpu')

# we will use matplotlib, arviz and seaborn for some of the plotting
import matplotlib.pyplot as plt
import arviz as az
import seaborn as sns

# disable some warning shown by importing LALSuite from a notebook
import warnings
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")

# import ringdown package
import ringdown as rd

# set plotting context
sns.set_context('notebook')
sns.set_palette('colorblind')

# import papermill and scrapbook for pipeline
import papermill as pm
import scrapbook as sb
from pathlib import Path

import pandas as pd
from ringdown.data import Data

# %%
plt.close('all')

# %% [markdown]
# From here on we might need to have a loop over each of the taper fcns

# %%
# SETTINGS
repo = Path.cwd().resolve()
while not (repo / 'README.md').exists():
    repo = repo.parent

bilby_dir = repo.parent / 'datadir' / 'bilby_output'
ringdown_dir = repo.parent / 'datadir' / 'ringdown_output'
inprefix = 'final'

df = pd.read_csv(bilby_dir / f'{inprefix}_injection_data.csv')
md = pd.read_csv(bilby_dir / f'{inprefix}_injection_metadata.csv')

num_modes = 1  # number of modes to use in ringdown model
analysis_start_time = 10.5 #in tMf, after merger peak
output_file = ringdown_dir / 'final_fit_result_1mode.nc'
duration = 0.4 #0.6 is what the paper used for ringdown, but 0.2 should be enough
num_chains = 4
num_samples = 2000

print('Input dir:', bilby_dir)
print('Output file:', output_file)
# Out:
# Input dir: /home/selmavangstein/mastersproject/datadir/bilby_output
# Output file: /home/selmavangstein/mastersproject/gw_boson_star_testing_gr/ringdown_results/test_fit_result_1mode.nc

# %%
if num_modes == 1:
    fit = rd.Fit(modes=[(1, -2, 2, 2, 0)])
elif num_modes == 2:
    fit = rd.Fit(modes=[(1, -2, 2, 2, 0), (1, -2, 2, 2, 1)])
else:
    raise ValueError("num_modes must be 1 or 2")

# Load parameters from metadata (time shifting already done in barebones_injection)
ra = md['ra'].values[0]  
dec = md['dec'].values[0]  
psi = md['psi'].values[0]
h1_arrival_time = md['h1_arrival_time'].values[0]  # Already in GPS time

# Data is already in GPS time coordinates with peaks at arrival times
h1_series = pd.Series(df['H1'].values, index=df['time'].values)
fit.add_data(h1_series, ifo='H1')
l1_series = pd.Series(df['L1'].values, index=df['time'].values)
fit.add_data(l1_series, ifo='L1')

# Set analysis start time relative to H1 arrival
t_Mf = 0.337e-3  # Time scale in seconds
start_offset = analysis_start_time * t_Mf  # Offset in units of t/Mf

fit.set_target(
    t0=h1_arrival_time + start_offset,
    ra=ra,
    dec=dec,
    psi=psi,
    duration=duration,
    reference_ifo='H1'
)

# %%
plt.figure()
for ifo, data in fit.data.items():
    data[::4].plot(label=ifo)
plt.xlabel(r'$t_\mathrm{GPS} / \mathrm{s}$');
plt.ylabel(r'$h(t)$');
plt.title('Initial data');
plt.legend(loc='best');
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Here are estimated noise PSDs for our data:

# %%
#recall that ASD = sqrt(PSD) - we have already plotted ASD for our sim data, so should be able to compare later
plt.figure()
for ifo, data in fit.data.items():
    plt.loglog(data.get_psd().iloc[1:], label=ifo)
plt.xlabel(r'$f / \mathrm{Hz}$');
plt.ylabel(r'$P\left( f \right) / \mathrm{Hz}^{-1}$');
plt.title('Initial PSD');
plt.legend(loc='best');
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Data conditioning

# %% [markdown]
# We condition the data - downsample by factor of 1 and set the f_min

# %%
fit.condition_data(ds=1, f_min=md['f_min'].values[0])
# already have the frequency that the paper had post conditioning

# %% [markdown]
# <div class="alert alert-info">
#
# Warning
#
# The conditioning function has a large number of options to manipulate the data in several ways. You should always make sure that the defaults make sense for your data!
#
# </div>

# %% [markdown]
# We can visualize the segment of conditioned analysis data as another sanity check:

# %%
# plot conditioned data
plt.figure()
for i, d in fit.analysis_data.items():
    d.plot(label=i)
    plt.axvline(fit.start_times[i], ls='--', alpha=0.5, lw=3, c='gray')
plt.xlabel(r'$t_\mathrm{GPS} / \mathrm{s}$');
plt.ylabel(r'$h(t)$');
plt.title('Conditioned data');
plt.legend(loc='best');
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# The wave arrived first at Livingston, then at Hanford, which is why the time segments are not exactly aligned.

# %% [markdown]
# #### Autocovariance function

# %% [markdown]
# A key ingredient in our likelihood calculation is the autocovariance function (ACF) of the noise, which is the time-domain equivalent of the power spectral density (PSD). You can load estimates of the ACF from disk, derive it from a PSD, or estimate it directly from the data. We do the latter below, with some default options.

# %%
fit.compute_acfs(f_min=md['f_min'].values[0])
# Out:
# /home/selmavangstein/miniconda3/envs/ringdown/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 32768 is greater than input length  = 11170, using nperseg = 11170
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/selmavangstein/miniconda3/envs/ringdown/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 32768 is greater than input length  = 11170, using nperseg = 11170
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,

# %% [markdown]
# We can use the ACFs to whiten the analysis data and plot it once again.

# %%
# plt.figure()
# wd = fit.whiten(fit.analysis_data)
# for i, d in wd.items():
#     d.plot(label=i)
# plt.xlabel(r'$t_\mathrm{GPS} / \mathrm{s}$');
# plt.ylabel(r'whitened $h(t)$');
# plt.title('Whitened data');
# plt.legend(loc='best');
# plt.show()

# %% [markdown]
# The signal is visible towards the beginning of the whitened data.

# %% [markdown]
# ### Run fit

# %% [markdown]
# We are almost ready to run the fit. Before sampling over the posterior on modes, we need to set up some priors with reasonable choices. We can see all the options available by using querying the `valid_model_settings` argument.

# %%
print(fit.valid_model_settings)
# Out:
# ['a_scale_max', 'marginalized', 'm_min', 'm_max', 'chi_min', 'chi_max', 'cosi_min', 'cosi_max', 'cosi', 'df_min', 'df_max', 'dg_min', 'dg_max', 'f_min', 'f_max', 'g_min', 'g_max', 'flat_amplitude_prior', 'mode_ordering', 'single_polarization']

# %% [markdown]
# These settings determine the prior and type of fit. For a vanilla Kerr fit with generic mode polarizations (not parametrized in terms of a source inclination), we only need to specify an amplitude scale, and a mass range.

# %% [markdown]
# We are finally ready to run! This should only take a couple of minutes on a modern desktop computer using CPUs.

# %%
# Estimate the peak strain in your analysis window
#peak_strain = max([d.abs().max() for d in fit.analysis_data.values()])
#a_max = 100 * peak_strain

# Set priors/bounds for amplitude scale, mass, spin
# adapt these based on expected values from the simulation
fit.update_model(a_scale_max=5e-20,
                 m_min=50.0,       # Min mass (solar masses)
                 m_max=85.0,      # Max mass (solar masses) 
                 chi_min=0.255,      # Min dimensionless spin
                 chi_max=0.95      # Max dimensionless spin
    )

# %%
fit.run(num_chains=num_chains, num_samples=num_samples)
# Out:
# WARNING:ringdown.fit:running with float32 precision
# WARNING:2026-03-20 17:33:15,134:jax._src.xla_bridge:969: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# WARNING:jax._src.xla_bridge:An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
#   0%|          | 0/3000 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]

# %%
fit.result
# Out:
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats
# 	> observed_data
# 	> constant_data

# %% [markdown]
# The result of our fit is held in `fit.result`. This is just an `arviz.InferenceData` object, with some additional ringdown-specific functionality. As such we can use all tools in ArViz easily.

# %%
# Check available methods
print(dir(fit.result))
# Out:
# ['InferenceDataItemsView', 'InferenceDataValuesView', '__abstractmethods__', '__add__', '__annotations__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_attrs', '_config_dict', '_config_object', '_default_label_format', '_df_parameters', '_generate_whitened_residuals', '_group_names', '_groups', '_groups_all', '_groups_warmup', '_imr_result', '_is_protocol', '_modes', '_repr_html_', '_target', '_whitened_templates', '_wrap_xarray_method', 'a_scale_max', 'add_groups', 'amplitude_significance', 'analysis_data', 'assign', 'assign_coords', 'attrs', 'cholesky_factors', 'chunk', 'close', 'compute', 'compute_posterior_snrs', 'config', 'constant_data', 'copy', 'cumsum', 'default_label_format', 'draw_sample', 'draw_strain_sample', 'epoch', 'ess', 'extend', 'from_datatree', 'from_netcdf', 'from_zarr', 'get', 'get_fit', 'get_index', 'get_mode_parameter_dataframe', 'get_parameter_dataframe', 'get_parameter_key_map', 'get_single_mode_dataframe', 'get_strain_quantile', 'groups', 'h_det', 'h_det_mode', 'has_imr_result', 'ifos', 'imr_consistency', 'imr_consistency_summary', 'imr_result', 'info', 'injected_strain', 'isel', 'items', 'keys', 'load', 'log_likelihood', 'log_likelihood_timeseries', 'loo', 'map', 'max', 'mean', 'median', 'min', 'modes', 'n_analyze', 'observed_data', 'observed_strain', 'persist', 'plot_mass_spin', 'plot_trace', 'posterior', 'quantile', 'rename', 'rename_dims', 'rename_vars', 'resample_to_uniform_amplitude', 'rescale_strain', 'reset_coords', 'reset_index', 'sample_stats', 'sample_times', 'sel', 'set_coords', 'set_dataframe_parameters', 'set_imr_result', 'set_index', 'sortby', 'stack', 'stacked_samples', 'start_times', 'strain_scale', 'sum', 't0', 'target', 'templates', 'to_dataframe', 'to_datatree', 'to_dict', 'to_json', 'to_netcdf', 'to_zarr', 'unify_chunks', 'unstack', 'update_default_label_format', 'values', 'waic', 'whiten', 'whitened_data', 'whitened_residuals', 'whitened_templates']

# %%
# store the fit.result object 
# if the output file does not exist, create it
#output_file = ringdown_dir / 'total_fit_result3.nc'
output = Path(output_file).with_suffix('.nc')  # Use .nc extension
output.parent.mkdir(exist_ok=True)
fit.result.to_netcdf(output)
# Out:
# PosixPath('/home/selmavangstein/mastersproject/gw_boson_star_testing_gr/ringdown_results/test_fit_result_1mode.nc')
